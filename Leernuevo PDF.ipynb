# %%
import fitz

# %% [markdown]
# # Importamos el PDF

# %%
pdf = "manual.pdf"
docum = fitz.open(pdf)

# %% [markdown]
# # Leemos el contenido del PDF y contamos el numero de paginas

# %%
print("numero de paginas: ",docum.pageCount)
np=docum.pageCount
iniciopagina=[]
for i in range(1,np+1):
    iniciopagina.append((247*i)-1)
# Out:
# numero de paginas:  1

# %% [markdown]
# # Leemos la primera pagina para inspeccionar el contenido leido

# %%
pagina = docum.load_page(0)
text = pagina.get_text("text")

# %%
print(text)
# Out:
# 32
#
#
#
#
# 1
# 122 x 22 =
# 2,684
# 2
# 216 x 22 =
# 4,752
# 3
# 314 x 22 =
# 6,908
# 4
# 417 x 22 =
# 9,174
# 5
# 512 x 22 =
# 11,264
# 6
# 613 x 22 =
# 13,486
# 7
# 718 x 22 =
# 15,796
# 8
# 819 x 22 =
# 18,018
# 9
# 930 x 22 =
# 20,460
# 10
# 807 x 22 =
# 17,754
# 1
# 981 x 22 =
# 21,582
# 2
# 863 x 22 =
# 18,986
# 3
# 744 x 22 =
# 16,368
# 4
# 635 x 22 =
# 13,970
# 5
# 529 x 22 =
# 11,638
# 6
# 478 x 22 =
# 10,516
# 7
# 391 x 22 =
# 8,602
# 8
# 217 x 22 =
# 4,774
# 9
# 173 x 22 =
# 3,806
# 10
# 702 x 22 =
# 15,444
# 1
# 997 x 22 =
# 21,934
# 2
# 127 x 22 =
# 2,794
# 3
# 839 x 22 =
# 18,458
# 4
# 257 x 22 =
# 5,654
# 5
# 793 x 22 =
# 17,446
# 6
# 375 x 22 =
# 8,250
# 7
# 646 x 22 =
# 14,212
# 8
# 477 x 22 =
# 10,494
# 9
# 576 x 22 =
# 12,672
# 10
# 606 x 22 =
# 13,332
# 1
# 557 x 22 =
# 12,254
# 2
# 619 x 22 =
# 13,618
# 3
# 715 x 22 =
# 15,730
# 4
# 826 x 22 =
# 18,172
# 5
# 972 x 22 =
# 21,384
# 6
# 135 x 22 =
# 2,970
# 7
# 219 x 22 =
# 4,818
# 8
# 326 x 22 =
# 7,172
# 9
# 418 x 22 =
# 9,196
# 10
# 207 x 22 =
# 4,554
# 1
# 230 x 22 =
# 5,060
# 2
# 429 x 22 =
# 9,438
# 3
# 695 x 22 =
# 15,290
# 4
# 812 x 22 =
# 17,864
# 5
# 181 x 22 =
# 3,982
# 6
# 329 x 22 =
# 7,238
# 7
# 537 x 22 =
# 11,814
# 8
# 709 x 22 =
# 15,598
# 9
# 914 x 22 =
# 20,108
# 10
# 105 x 22 =
# 2,310
# 1
# 135 x 22 =
# 2,970
# 2
# 356 x 22 =
# 7,832
# 3
# 578 x 22 =
# 12,716
# 4
# 799 x 22 =
# 17,578
# 5
# 936 x 22 =
# 20,592
# 6
# 244 x 22 =
# 5,368
# 7
# 445 x 22 =
# 9,790
# 8
# 672 x 22 =
# 14,784
# 9
# 831 x 22 =
# 18,282
# 10
# 903 x 22 =
# 19,866
# EFICIENCIA
# %
# Dominio intermedio - 8 - Lección - 1
# Cálculo con el Tika
# Multiplicación de 3 dígitos por 2 dígitos
# Eficiencia Mínima: 75 %

# %%
len(text)
# Out:
# 1519

# %% [markdown]
# # Guardamos en TXT para poder leer y tratar los datos como matriz

# %%
import os
salida = open("prueba.txt","wb")

for pag in docum:
    texto =pag.get_text().encode("utf8")
    salida.write(texto)
salida.close()

# %%
txt = open("prueba.txt","r",encoding="utf8")
cont= txt.readlines()
txt.close()
len(cont)
cont
# Out:
# ['32 \n',
#  ' \n',
#  ' \n',
#  ' \n',
#  ' \n',
#  '1 \n',
#  '122 x 22 = \n',
#  '2,684 \n',
#  '2 \n',
#  '216 x 22 = \n',
#  '4,752 \n',
#  '3 \n',
#  '314 x 22 = \n',
#  '6,908 \n',
#  '4 \n',
#  '417 x 22 = \n',
#  '9,174 \n',
#  '5 \n',
#  '512 x 22 = \n',
#  '11,264 \n',
#  '6 \n',
#  '613 x 22 = \n',
#  '13,486 \n',
#  '7 \n',
#  '718 x 22 = \n',
#  '15,796 \n',
#  '8 \n',
#  '819 x 22 = \n',
#  '18,018 \n',
#  '9 \n',
#  '930 x 22 = \n',
#  '20,460 \n',
#  '10 \n',
#  '807 x 22 = \n',
#  '17,754 \n',
#  '1 \n',
#  '981 x 22 = \n',
#  '21,582 \n',
#  '2 \n',
#  '863 x 22 = \n',
#  '18,986 \n',
#  '3 \n',
#  '744 x 22 = \n',
#  '16,368 \n',
#  '4 \n',
#  '635 x 22 = \n',
#  '13,970 \n',
#  '5 \n',
#  '529 x 22 = \n',
#  '11,638 \n',
#  '6 \n',
#  '478 x 22 = \n',
#  '10,516 \n',
#  '7 \n',
#  '391 x 22 = \n',
#  '8,602 \n',
#  '8 \n',
#  '217 x 22 = \n',
#  '4,774 \n',
#  '9 \n',
#  '173 x 22 = \n',
#  '3,806 \n',
#  '10 \n',
#  '702 x 22 = \n',
#  '15,444 \n',
#  '1 \n',
#  '997 x 22 = \n',
#  '21,934 \n',
#  '2 \n',
#  '127 x 22 = \n',
#  '2,794 \n',
#  '3 \n',
#  '839 x 22 = \n',
#  '18,458 \n',
#  '4 \n',
#  '257 x 22 = \n',
#  '5,654 \n',
#  '5 \n',
#  '793 x 22 = \n',
#  '17,446 \n',
#  '6 \n',
#  '375 x 22 = \n',
#  '8,250 \n',
#  '7 \n',
#  '646 x 22 = \n',
#  '14,212 \n',
#  '8 \n',
#  '477 x 22 = \n',
#  '10,494 \n',
#  '9 \n',
#  '576 x 22 = \n',
#  '12,672 \n',
#  '10 \n',
#  '606 x 22 = \n',
#  '13,332 \n',
#  '1 \n',
#  '557 x 22 = \n',
#  '12,254 \n',
#  '2 \n',
#  '619 x 22 = \n',
#  '13,618 \n',
#  '3 \n',
#  '715 x 22 = \n',
#  '15,730 \n',
#  '4 \n',
#  '826 x 22 = \n',
#  '18,172 \n',
#  '5 \n',
#  '972 x 22 = \n',
#  '21,384 \n',
#  '6 \n',
#  '135 x 22 = \n',
#  '2,970 \n',
#  '7 \n',
#  '219 x 22 = \n',
#  '4,818 \n',
#  '8 \n',
#  '326 x 22 = \n',
#  '7,172 \n',
#  '9 \n',
#  '418 x 22 = \n',
#  '9,196 \n',
#  '10 \n',
#  '207 x 22 = \n',
#  '4,554 \n',
#  '1 \n',
#  '230 x 22 = \n',
#  '5,060 \n',
#  '2 \n',
#  '429 x 22 = \n',
#  '9,438 \n',
#  '3 \n',
#  '695 x 22 = \n',
#  '15,290 \n',
#  '4 \n',
#  '812 x 22 = \n',
#  '17,864 \n',
#  '5 \n',
#  '181 x 22 = \n',
#  '3,982 \n',
#  '6 \n',
#  '329 x 22 = \n',
#  '7,238 \n',
#  '7 \n',
#  '537 x 22 = \n',
#  '11,814 \n',
#  '8 \n',
#  '709 x 22 = \n',
#  '15,598 \n',
#  '9 \n',
#  '914 x 22 = \n',
#  '20,108 \n',
#  '10 \n',
#  '105 x 22 = \n',
#  '2,310 \n',
#  '1 \n',
#  '135 x 22 = \n',
#  '2,970 \n',
#  '2 \n',
#  '356 x 22 = \n',
#  '7,832 \n',
#  '3 \n',
#  '578 x 22 = \n',
#  '12,716 \n',
#  '4 \n',
#  '799 x 22 = \n',
#  '17,578 \n',
#  '5 \n',
#  '936 x 22 = \n',
#  '20,592 \n',
#  '6 \n',
#  '244 x 22 = \n',
#  '5,368 \n',
#  '7 \n',
#  '445 x 22 = \n',
#  '9,790 \n',
#  '8 \n',
#  '672 x 22 = \n',
#  '14,784 \n',
#  '9 \n',
#  '831 x 22 = \n',
#  '18,282 \n',
#  '10 \n',
#  '903 x 22 = \n',
#  '19,866 \n',
#  'EFICIENCIA \n',
#  '% \n',
#  'Dominio intermedio - 8 - Lección - 1  \n',
#  'Cálculo con el Tika \n',
#  'Multiplicación de 3 dígitos por 2 dígitos \n',
#  'Eficiencia Mínima: 75 % \n',
#  ' \n']

# %% [markdown]
# # Eliminamos espacios en blanco

# %%
noneElement=[]
for i in range(0,len(cont)):
    if cont[i] == " \n":
        noneElement.append(i)
a = len(noneElement)
for i in range(0,a):
    cont.remove(" \n")
print(len(cont))
# Out:
# 187

# %%
cont2=[]
for i in range(0,len(cont)):
    aux=cont[i].split(sep=' \n')
    cont2.append(aux[0])
cont2
# Out:
# ['32',
#  '1',
#  '122 x 22 =',
#  '2,684',
#  '2',
#  '216 x 22 =',
#  '4,752',
#  '3',
#  '314 x 22 =',
#  '6,908',
#  '4',
#  '417 x 22 =',
#  '9,174',
#  '5',
#  '512 x 22 =',
#  '11,264',
#  '6',
#  '613 x 22 =',
#  '13,486',
#  '7',
#  '718 x 22 =',
#  '15,796',
#  '8',
#  '819 x 22 =',
#  '18,018',
#  '9',
#  '930 x 22 =',
#  '20,460',
#  '10',
#  '807 x 22 =',
#  '17,754',
#  '1',
#  '981 x 22 =',
#  '21,582',
#  '2',
#  '863 x 22 =',
#  '18,986',
#  '3',
#  '744 x 22 =',
#  '16,368',
#  '4',
#  '635 x 22 =',
#  '13,970',
#  '5',
#  '529 x 22 =',
#  '11,638',
#  '6',
#  '478 x 22 =',
#  '10,516',
#  '7',
#  '391 x 22 =',
#  '8,602',
#  '8',
#  '217 x 22 =',
#  '4,774',
#  '9',
#  '173 x 22 =',
#  '3,806',
#  '10',
#  '702 x 22 =',
#  '15,444',
#  '1',
#  '997 x 22 =',
#  '21,934',
#  '2',
#  '127 x 22 =',
#  '2,794',
#  '3',
#  '839 x 22 =',
#  '18,458',
#  '4',
#  '257 x 22 =',
#  '5,654',
#  '5',
#  '793 x 22 =',
#  '17,446',
#  '6',
#  '375 x 22 =',
#  '8,250',
#  '7',
#  '646 x 22 =',
#  '14,212',
#  '8',
#  '477 x 22 =',
#  '10,494',
#  '9',
#  '576 x 22 =',
#  '12,672',
#  '10',
#  '606 x 22 =',
#  '13,332',
#  '1',
#  '557 x 22 =',
#  '12,254',
#  '2',
#  '619 x 22 =',
#  '13,618',
#  '3',
#  '715 x 22 =',
#  '15,730',
#  '4',
#  '826 x 22 =',
#  '18,172',
#  '5',
#  '972 x 22 =',
#  '21,384',
#  '6',
#  '135 x 22 =',
#  '2,970',
#  '7',
#  '219 x 22 =',
#  '4,818',
#  '8',
#  '326 x 22 =',
#  '7,172',
#  '9',
#  '418 x 22 =',
#  '9,196',
#  '10',
#  '207 x 22 =',
#  '4,554',
#  '1',
#  '230 x 22 =',
#  '5,060',
#  '2',
#  '429 x 22 =',
#  '9,438',
#  '3',
#  '695 x 22 =',
#  '15,290',
#  '4',
#  '812 x 22 =',
#  '17,864',
#  '5',
#  '181 x 22 =',
#  '3,982',
#  '6',
#  '329 x 22 =',
#  '7,238',
#  '7',
#  '537 x 22 =',
#  '11,814',
#  '8',
#  '709 x 22 =',
#  '15,598',
#  '9',
#  '914 x 22 =',
#  '20,108',
#  '10',
#  '105 x 22 =',
#  '2,310',
#  '1',
#  '135 x 22 =',
#  '2,970',
#  '2',
#  '356 x 22 =',
#  '7,832',
#  '3',
#  '578 x 22 =',
#  '12,716',
#  '4',
#  '799 x 22 =',
#  '17,578',
#  '5',
#  '936 x 22 =',
#  '20,592',
#  '6',
#  '244 x 22 =',
#  '5,368',
#  '7',
#  '445 x 22 =',
#  '9,790',
#  '8',
#  '672 x 22 =',
#  '14,784',
#  '9',
#  '831 x 22 =',
#  '18,282',
#  '10',
#  '903 x 22 =',
#  '19,866',
#  'EFICIENCIA',
#  '%',
#  'Dominio intermedio - 8 - Lección - 1 ',
#  'Cálculo con el Tika',
#  'Multiplicación de 3 dígitos por 2 dígitos',
#  'Eficiencia Mínima: 75 %']

# %%
cont2[2]
# Out:
# '122 x 22 ='

# %% [markdown]
# # Eliminamos los signos de igual

# %%
cont3 = []
for i in range(0,len(cont2)):
    aux=cont2[i].split(sep=' =')
    cont3.append(aux[0])
cont3
# Out:
# ['32',
#  '1',
#  '122 x 22',
#  '2,684',
#  '2',
#  '216 x 22',
#  '4,752',
#  '3',
#  '314 x 22',
#  '6,908',
#  '4',
#  '417 x 22',
#  '9,174',
#  '5',
#  '512 x 22',
#  '11,264',
#  '6',
#  '613 x 22',
#  '13,486',
#  '7',
#  '718 x 22',
#  '15,796',
#  '8',
#  '819 x 22',
#  '18,018',
#  '9',
#  '930 x 22',
#  '20,460',
#  '10',
#  '807 x 22',
#  '17,754',
#  '1',
#  '981 x 22',
#  '21,582',
#  '2',
#  '863 x 22',
#  '18,986',
#  '3',
#  '744 x 22',
#  '16,368',
#  '4',
#  '635 x 22',
#  '13,970',
#  '5',
#  '529 x 22',
#  '11,638',
#  '6',
#  '478 x 22',
#  '10,516',
#  '7',
#  '391 x 22',
#  '8,602',
#  '8',
#  '217 x 22',
#  '4,774',
#  '9',
#  '173 x 22',
#  '3,806',
#  '10',
#  '702 x 22',
#  '15,444',
#  '1',
#  '997 x 22',
#  '21,934',
#  '2',
#  '127 x 22',
#  '2,794',
#  '3',
#  '839 x 22',
#  '18,458',
#  '4',
#  '257 x 22',
#  '5,654',
#  '5',
#  '793 x 22',
#  '17,446',
#  '6',
#  '375 x 22',
#  '8,250',
#  '7',
#  '646 x 22',
#  '14,212',
#  '8',
#  '477 x 22',
#  '10,494',
#  '9',
#  '576 x 22',
#  '12,672',
#  '10',
#  '606 x 22',
#  '13,332',
#  '1',
#  '557 x 22',
#  '12,254',
#  '2',
#  '619 x 22',
#  '13,618',
#  '3',
#  '715 x 22',
#  '15,730',
#  '4',
#  '826 x 22',
#  '18,172',
#  '5',
#  '972 x 22',
#  '21,384',
#  '6',
#  '135 x 22',
#  '2,970',
#  '7',
#  '219 x 22',
#  '4,818',
#  '8',
#  '326 x 22',
#  '7,172',
#  '9',
#  '418 x 22',
#  '9,196',
#  '10',
#  '207 x 22',
#  '4,554',
#  '1',
#  '230 x 22',
#  '5,060',
#  '2',
#  '429 x 22',
#  '9,438',
#  '3',
#  '695 x 22',
#  '15,290',
#  '4',
#  '812 x 22',
#  '17,864',
#  '5',
#  '181 x 22',
#  '3,982',
#  '6',
#  '329 x 22',
#  '7,238',
#  '7',
#  '537 x 22',
#  '11,814',
#  '8',
#  '709 x 22',
#  '15,598',
#  '9',
#  '914 x 22',
#  '20,108',
#  '10',
#  '105 x 22',
#  '2,310',
#  '1',
#  '135 x 22',
#  '2,970',
#  '2',
#  '356 x 22',
#  '7,832',
#  '3',
#  '578 x 22',
#  '12,716',
#  '4',
#  '799 x 22',
#  '17,578',
#  '5',
#  '936 x 22',
#  '20,592',
#  '6',
#  '244 x 22',
#  '5,368',
#  '7',
#  '445 x 22',
#  '9,790',
#  '8',
#  '672 x 22',
#  '14,784',
#  '9',
#  '831 x 22',
#  '18,282',
#  '10',
#  '903 x 22',
#  '19,866',
#  'EFICIENCIA',
#  '%',
#  'Dominio intermedio - 8 - Lección - 1 ',
#  'Cálculo con el Tika',
#  'Multiplicación de 3 dígitos por 2 dígitos',
#  'Eficiencia Mínima: 75 %']

# %%
for i in range(0,len(cont3)):
    print("Linea:{} texto: {}".format(i,cont3[i]))
# Out:
# Linea:0 texto: 32
# Linea:1 texto: 1
# Linea:2 texto: 122 x 22
# Linea:3 texto: 2,684
# Linea:4 texto: 2
# Linea:5 texto: 216 x 22
# Linea:6 texto: 4,752
# Linea:7 texto: 3
# Linea:8 texto: 314 x 22
# Linea:9 texto: 6,908
# Linea:10 texto: 4
# Linea:11 texto: 417 x 22
# Linea:12 texto: 9,174
# Linea:13 texto: 5
# Linea:14 texto: 512 x 22
# Linea:15 texto: 11,264
# Linea:16 texto: 6
# Linea:17 texto: 613 x 22
# Linea:18 texto: 13,486
# Linea:19 texto: 7
# Linea:20 texto: 718 x 22
# Linea:21 texto: 15,796
# Linea:22 texto: 8
# Linea:23 texto: 819 x 22
# Linea:24 texto: 18,018
# Linea:25 texto: 9
# Linea:26 texto: 930 x 22
# Linea:27 texto: 20,460
# Linea:28 texto: 10
# Linea:29 texto: 807 x 22
# Linea:30 texto: 17,754
# Linea:31 texto: 1
# Linea:32 texto: 981 x 22
# Linea:33 texto: 21,582
# Linea:34 texto: 2
# Linea:35 texto: 863 x 22
# Linea:36 texto: 18,986
# Linea:37 texto: 3
# Linea:38 texto: 744 x 22
# Linea:39 texto: 16,368
# Linea:40 texto: 4
# Linea:41 texto: 635 x 22
# Linea:42 texto: 13,970
# Linea:43 texto: 5
# Linea:44 texto: 529 x 22
# Linea:45 texto: 11,638
# Linea:46 texto: 6
# Linea:47 texto: 478 x 22
# Linea:48 texto: 10,516
# Linea:49 texto: 7
# Linea:50 texto: 391 x 22
# Linea:51 texto: 8,602
# Linea:52 texto: 8
# Linea:53 texto: 217 x 22
# Linea:54 texto: 4,774
# Linea:55 texto: 9
# Linea:56 texto: 173 x 22
# Linea:57 texto: 3,806
# Linea:58 texto: 10
# Linea:59 texto: 702 x 22
# Linea:60 texto: 15,444
# Linea:61 texto: 1
# Linea:62 texto: 997 x 22
# Linea:63 texto: 21,934
# Linea:64 texto: 2
# Linea:65 texto: 127 x 22
# Linea:66 texto: 2,794
# Linea:67 texto: 3
# Linea:68 texto: 839 x 22
# Linea:69 texto: 18,458
# Linea:70 texto: 4
# Linea:71 texto: 257 x 22
# Linea:72 texto: 5,654
# Linea:73 texto: 5
# Linea:74 texto: 793 x 22
# Linea:75 texto: 17,446
# Linea:76 texto: 6
# Linea:77 texto: 375 x 22
# Linea:78 texto: 8,250
# Linea:79 texto: 7
# Linea:80 texto: 646 x 22
# Linea:81 texto: 14,212
# Linea:82 texto: 8
# Linea:83 texto: 477 x 22
# Linea:84 texto: 10,494
# Linea:85 texto: 9
# Linea:86 texto: 576 x 22
# Linea:87 texto: 12,672
# Linea:88 texto: 10
# Linea:89 texto: 606 x 22
# Linea:90 texto: 13,332
# Linea:91 texto: 1
# Linea:92 texto: 557 x 22
# Linea:93 texto: 12,254
# Linea:94 texto: 2
# Linea:95 texto: 619 x 22
# Linea:96 texto: 13,618
# Linea:97 texto: 3
# Linea:98 texto: 715 x 22
# Linea:99 texto: 15,730
# Linea:100 texto: 4
# Linea:101 texto: 826 x 22
# Linea:102 texto: 18,172
# Linea:103 texto: 5
# Linea:104 texto: 972 x 22
# Linea:105 texto: 21,384
# Linea:106 texto: 6
# Linea:107 texto: 135 x 22
# Linea:108 texto: 2,970
# Linea:109 texto: 7
# Linea:110 texto: 219 x 22
# Linea:111 texto: 4,818
# Linea:112 texto: 8
# Linea:113 texto: 326 x 22
# Linea:114 texto: 7,172
# Linea:115 texto: 9
# Linea:116 texto: 418 x 22
# Linea:117 texto: 9,196
# Linea:118 texto: 10
# Linea:119 texto: 207 x 22
# Linea:120 texto: 4,554
# Linea:121 texto: 1
# Linea:122 texto: 230 x 22
# Linea:123 texto: 5,060
# Linea:124 texto: 2
# Linea:125 texto: 429 x 22
# Linea:126 texto: 9,438
# Linea:127 texto: 3
# Linea:128 texto: 695 x 22
# Linea:129 texto: 15,290
# Linea:130 texto: 4
# Linea:131 texto: 812 x 22
# Linea:132 texto: 17,864
# Linea:133 texto: 5
# Linea:134 texto: 181 x 22
# Linea:135 texto: 3,982
# Linea:136 texto: 6
# Linea:137 texto: 329 x 22
# Linea:138 texto: 7,238
# Linea:139 texto: 7
# Linea:140 texto: 537 x 22
# Linea:141 texto: 11,814
# Linea:142 texto: 8
# Linea:143 texto: 709 x 22
# Linea:144 texto: 15,598
# Linea:145 texto: 9
# Linea:146 texto: 914 x 22
# Linea:147 texto: 20,108
# Linea:148 texto: 10
# Linea:149 texto: 105 x 22
# Linea:150 texto: 2,310
# Linea:151 texto: 1
# Linea:152 texto: 135 x 22
# Linea:153 texto: 2,970
# Linea:154 texto: 2
# Linea:155 texto: 356 x 22
# Linea:156 texto: 7,832
# Linea:157 texto: 3
# Linea:158 texto: 578 x 22
# Linea:159 texto: 12,716
# Linea:160 texto: 4
# Linea:161 texto: 799 x 22
# Linea:162 texto: 17,578
# Linea:163 texto: 5
# Linea:164 texto: 936 x 22
# Linea:165 texto: 20,592
# Linea:166 texto: 6
# Linea:167 texto: 244 x 22
# Linea:168 texto: 5,368
# Linea:169 texto: 7
# Linea:170 texto: 445 x 22
# Linea:171 texto: 9,790
# Linea:172 texto: 8
# Linea:173 texto: 672 x 22
# Linea:174 texto: 14,784
# Linea:175 texto: 9
# Linea:176 texto: 831 x 22
# Linea:177 texto: 18,282
# Linea:178 texto: 10
# Linea:179 texto: 903 x 22
# Linea:180 texto: 19,866
# Linea:181 texto: EFICIENCIA
# Linea:182 texto: %
# Linea:183 texto: Dominio intermedio - 8 - Lección - 1
# Linea:184 texto: Cálculo con el Tika
# Linea:185 texto: Multiplicación de 3 dígitos por 2 dígitos
# Linea:186 texto: Eficiencia Mínima: 75 %

# %% [markdown]
# # Se obtienen todas las multiplicaciones de la hoja

# %%
mult =[]
resM = []
for i in range(2,180,3):
    mult.append(cont3[i])
for i in range(3,181,3):
    resM.append(cont3[i])

# %%
multip = []
auxlistaTab =[]
multipR=[]
auxlistaTabR =[]
for i in range(0,61):
    if(i<10):
        auxlistaTab.append(mult[i])
        auxlistaTabR.append(resM[i])
    elif(i==10):
        multip.append(auxlistaTab)
        auxlistaTab =[]
        multipR.append(auxlistaTabR)
        auxlistaTabR =[]
    if(i<20 and i>=10):
        auxlistaTab.append(mult[i])
        auxlistaTabR.append(resM[i])
    elif(i==20):
        multip.append(auxlistaTab)
        auxlistaTab =[]
        multipR.append(auxlistaTabR)
        auxlistaTabR =[]
    if(i<30 and i>=20):
        auxlistaTab.append(mult[i])
        auxlistaTabR.append(resM[i])
    elif(i==30):
        multip.append(auxlistaTab)
        auxlistaTab =[]
        multipR.append(auxlistaTabR)
        auxlistaTabR =[]
    if(i<40 and i >=30):
        auxlistaTab.append(mult[i])
        auxlistaTabR.append(resM[i])
    elif(i==40):
        multip.append(auxlistaTab)
        auxlistaTab =[]
        multipR.append(auxlistaTabR)
        auxlistaTabR =[]
    if(i<50 and i >=40):
        auxlistaTab.append(mult[i])
        auxlistaTabR.append(resM[i])
    elif(i==50):
        multip.append(auxlistaTab)
        auxlistaTab =[]
        multipR.append(auxlistaTabR)
        auxlistaTabR =[]
    if(i<60 and i >=50):
        auxlistaTab.append(mult[i])
        auxlistaTabR.append(resM[i])
    elif(i==60):
        multip.append(auxlistaTab)
        auxlistaTab =[]
        multipR.append(auxlistaTabR)
        auxlistaTabR =[]

    
#multip.append(auxlistaTab)

# %%
multip
# Out:
# [['122 x 22',
#   '216 x 22',
#   '314 x 22',
#   '417 x 22',
#   '512 x 22',
#   '613 x 22',
#   '718 x 22',
#   '819 x 22',
#   '930 x 22',
#   '807 x 22'],
#  ['981 x 22',
#   '863 x 22',
#   '744 x 22',
#   '635 x 22',
#   '529 x 22',
#   '478 x 22',
#   '391 x 22',
#   '217 x 22',
#   '173 x 22',
#   '702 x 22'],
#  ['997 x 22',
#   '127 x 22',
#   '839 x 22',
#   '257 x 22',
#   '793 x 22',
#   '375 x 22',
#   '646 x 22',
#   '477 x 22',
#   '576 x 22',
#   '606 x 22'],
#  ['557 x 22',
#   '619 x 22',
#   '715 x 22',
#   '826 x 22',
#   '972 x 22',
#   '135 x 22',
#   '219 x 22',
#   '326 x 22',
#   '418 x 22',
#   '207 x 22'],
#  ['230 x 22',
#   '429 x 22',
#   '695 x 22',
#   '812 x 22',
#   '181 x 22',
#   '329 x 22',
#   '537 x 22',
#   '709 x 22',
#   '914 x 22',
#   '105 x 22'],
#  ['135 x 22',
#   '356 x 22',
#   '578 x 22',
#   '799 x 22',
#   '936 x 22',
#   '244 x 22',
#   '445 x 22',
#   '672 x 22',
#   '831 x 22',
#   '903 x 22']]

# %%
multipR
# Out:
# [['2,684',
#   '4,752',
#   '6,908',
#   '9,174',
#   '11,264',
#   '13,486',
#   '15,796',
#   '18,018',
#   '20,460',
#   '17,754'],
#  ['21,582',
#   '18,986',
#   '16,368',
#   '13,970',
#   '11,638',
#   '10,516',
#   '8,602',
#   '4,774',
#   '3,806',
#   '15,444'],
#  ['21,934',
#   '2,794',
#   '18,458',
#   '5,654',
#   '17,446',
#   '8,250',
#   '14,212',
#   '10,494',
#   '12,672',
#   '13,332'],
#  ['12,254',
#   '13,618',
#   '15,730',
#   '18,172',
#   '21,384',
#   '2,970',
#   '4,818',
#   '7,172',
#   '9,196',
#   '4,554'],
#  ['5,060',
#   '9,438',
#   '15,290',
#   '17,864',
#   '3,982',
#   '7,238',
#   '11,814',
#   '15,598',
#   '20,108',
#   '2,310'],
#  ['2,970',
#   '7,832',
#   '12,716',
#   '17,578',
#   '20,592',
#   '5,368',
#   '9,790',
#   '14,784',
#   '18,282',
#   '19,866']]

# %%
hojaT =[]

# %%
def separaMultiplos(a):
    return a.split(sep=' x ')

# %%
tabla = []
for j in range(0,6):
    for i in range(0,10):
        m = separaMultiplos(multip[j][i])
        tabla.append(m)
        tabla[i].append(multipR[j][i])
    hojaT.append(tabla)
    tabla = []
hojaT
# Out:
# [[['122', '22', '2,684'],
#   ['216', '22', '4,752'],
#   ['314', '22', '6,908'],
#   ['417', '22', '9,174'],
#   ['512', '22', '11,264'],
#   ['613', '22', '13,486'],
#   ['718', '22', '15,796'],
#   ['819', '22', '18,018'],
#   ['930', '22', '20,460'],
#   ['807', '22', '17,754']],
#  [['981', '22', '21,582'],
#   ['863', '22', '18,986'],
#   ['744', '22', '16,368'],
#   ['635', '22', '13,970'],
#   ['529', '22', '11,638'],
#   ['478', '22', '10,516'],
#   ['391', '22', '8,602'],
#   ['217', '22', '4,774'],
#   ['173', '22', '3,806'],
#   ['702', '22', '15,444']],
#  [['997', '22', '21,934'],
#   ['127', '22', '2,794'],
#   ['839', '22', '18,458'],
#   ['257', '22', '5,654'],
#   ['793', '22', '17,446'],
#   ['375', '22', '8,250'],
#   ['646', '22', '14,212'],
#   ['477', '22', '10,494'],
#   ['576', '22', '12,672'],
#   ['606', '22', '13,332']],
#  [['557', '22', '12,254'],
#   ['619', '22', '13,618'],
#   ['715', '22', '15,730'],
#   ['826', '22', '18,172'],
#   ['972', '22', '21,384'],
#   ['135', '22', '2,970'],
#   ['219', '22', '4,818'],
#   ['326', '22', '7,172'],
#   ['418', '22', '9,196'],
#   ['207', '22', '4,554']],
#  [['230', '22', '5,060'],
#   ['429', '22', '9,438'],
#   ['695', '22', '15,290'],
#   ['812', '22', '17,864'],
#   ['181', '22', '3,982'],
#   ['329', '22', '7,238'],
#   ['537', '22', '11,814'],
#   ['709', '22', '15,598'],
#   ['914', '22', '20,108'],
#   ['105', '22', '2,310']],
#  [['135', '22', '2,970'],
#   ['356', '22', '7,832'],
#   ['578', '22', '12,716'],
#   ['799', '22', '17,578'],
#   ['936', '22', '20,592'],
#   ['244', '22', '5,368'],
#   ['445', '22', '9,790'],
#   ['672', '22', '14,784'],
#   ['831', '22', '18,282'],
#   ['903', '22', '19,866']]]

# %%
# Out:
# 6
